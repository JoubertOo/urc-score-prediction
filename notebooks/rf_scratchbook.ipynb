# %%
import pandas as pd
import numpy as np
import re

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error
from pathlib import Path

# --- function to convert datetime ---
def parse_sa(s: str):
    if pd.isna(s):
        return pd.NaT
    s = re.sub(r'(\b\d{1,2})(st|nd|rd|th)\b', r'\1', s)     # 20th -> 20
    s = s.replace("SAST", "").strip()                       # drop SAST
    dt = pd.to_datetime(s, dayfirst=True, errors="coerce")  # tz-naive
    return dt

# %%
import os
from pathlib import Path

print("CWD:", os.getcwd())
# Out:
# CWD: c:\Very old laptop\Betting\urc-score-prediction
# Resolved: C:\Very old laptop\Betting\data\processed\matches_with_weather_features24.csv
# Exists? False

# %%
# --- Load data ---
df = pd.read_csv("data/processed/matches_with_weather_features24.csv")

# Parse datetime and sort for time-aware CV
df["Date_time"] = pd.to_datetime(df["Date_time"])
df = df.sort_values("Date_time").reset_index(drop=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 20th September 2024, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 21st September 2024, 04:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 21st September 2024, 06:30pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 21st September 2024, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 21st September 2024, 08:45pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 27th September 2024, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 28th September 2024, 12:55pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 28th September 2024, 03:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 28th September 2024, 04:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 28th September 2024, 06:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 28th September 2024, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 4th October 2024, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 5th October 2024, 01:45pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 5th October 2024, 04:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 5th October 2024, 06:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 5th October 2024, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 11th October 2024, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 12th October 2024, 04:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 12th October 2024, 06:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 12th October 2024, 06:45pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 12th October 2024, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 12th October 2024, 09:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sun 13th October 2024, 03:30pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 18th October 2024, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 19th October 2024, 01:30pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 19th October 2024, 03:45pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 19th October 2024, 06:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 19th October 2024, 06:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 19th October 2024, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 25th October 2024, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 26th October 2024, 01:45pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 26th October 2024, 04:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 26th October 2024, 06:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 26th October 2024, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 29th November 2024, 09:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 30th November 2024, 05:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 30th November 2024, 07:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 30th November 2024, 07:30pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 30th November 2024, 09:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 20th December 2024, 09:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 21st December 2024, 03:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 21st December 2024, 03:45pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 21st December 2024, 06:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 21st December 2024, 07:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 21st December 2024, 07:30pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sun 22nd December 2024, 05:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Thu 26th December 2024, 07:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 27th December 2024, 09:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 28th December 2024, 05:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 28th December 2024, 09:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Wed 1st January 2025, 05:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Wed 1st January 2025, 07:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 24th January 2025, 09:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 25th January 2025, 02:45pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 25th January 2025, 05:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 25th January 2025, 07:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 25th January 2025, 07:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 25th January 2025, 09:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sun 26th January 2025, 05:30pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sun 26th January 2025, 07:30pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 8th February 2025, 02:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 14th February 2025, 09:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 15th February 2025, 02:30pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 15th February 2025, 05:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 15th February 2025, 07:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 15th February 2025, 09:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sun 16th February 2025, 04:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 22nd February 2025, 02:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 28th February 2025, 09:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 1st March 2025, 02:30pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 1st March 2025, 05:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 1st March 2025, 06:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 1st March 2025, 07:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 1st March 2025, 09:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 8th March 2025, 02:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 21st March 2025, 09:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 22nd March 2025, 02:45pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 22nd March 2025, 05:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 22nd March 2025, 07:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 28th March 2025, 09:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 29th March 2025, 02:45pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 29th March 2025, 04:30pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 29th March 2025, 05:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 29th March 2025, 07:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 29th March 2025, 09:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 18th April 2025, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 19th April 2025, 01:45pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 19th April 2025, 04:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 19th April 2025, 06:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 19th April 2025, 06:30pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 19th April 2025, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 25th April 2025, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 26th April 2025, 04:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 26th April 2025, 06:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 26th April 2025, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 9th May 2025, 07:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 9th May 2025, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 10th May 2025, 04:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 10th May 2025, 06:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 10th May 2025, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sun 11th May 2025, 03:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 16th May 2025, 07:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 16th May 2025, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 16th May 2025, 09:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 17th May 2025, 03:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 17th May 2025, 05:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 17th May 2025, 06:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 17th May 2025, 07:30pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 17th May 2025, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Fri 30th May 2025, 08:35pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 31st May 2025, 01:30pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 31st May 2025, 04:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 31st May 2025, 06:30pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 7th June 2025, 03:45pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 7th June 2025, 06:15pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28740\1972762393.py:5: FutureWarning: Parsed string "Sat 14th June 2025, 06:00pm SAST" included an un-recognized timezone "SAST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date_time"] = pd.to_datetime(df["Date_time"])

# %%
# --- Select features and targets ---
X_cols = ["Home_team","Away_team","Venue","wx_temp_c","wx_summary",
          "time_bucket","is_in_south_africa","is_main_home_stadium"]

Y_ht_cols = ["Halftime_score_home","Halftime_score_away"]
Y_ft_cols = ["Fulltime_score_home","Fulltime_score_away"]

X = df[X_cols]
Y_ht = df[Y_ht_cols].values
Y_ft = df[Y_ft_cols].values

# %%
# --- Preprocessing ---
cat = ["Home_team", "Away_team", "Venue", "wx_summary", "time_bucket", "is_in_south_africa", "is_main_home_stadium"]
num = ["wx_temp_c"]

# OneHotEncoder
prep = ColumnTransformer([
    ("cat", OneHotEncoder(handle_unknown="ignore"), cat),
    ("num", "passthrough", num),
])

# %%
# --- Model ---
rf_ht = RandomForestRegressor(n_estimators=600, min_samples_leaf=2, n_jobs=-1, random_state=42)
rf_ft = RandomForestRegressor(n_estimators=600, min_samples_leaf=2, n_jobs=-1, random_state=42)

pipe_ht = Pipeline([("prep", prep), ("rf", rf_ht)])
pipe_ft = Pipeline([("prep", prep), ("rf", rf_ft)])

# %%
np.zeros(Y_ht.shape[1])
# Out:
# array([0., 0.])

# %%
# --- 5-fold TimeSeriesSplit CV ---
tscv = TimeSeriesSplit(n_splits=5)

def cv_mae(pipe, X, Y):
    total_abs = np.zeros(Y.shape[1]); total_n = 0
    for tr, te in tscv.split(X):
        pipe.fit(X.iloc[tr], Y[tr])
        pred = np.clip(pipe.predict(X.iloc[te]), 0, None)
        total_abs += np.sum(np.abs(Y[te] - pred), axis=0)
        print(total_abs)
        total_n += len(te)
        print(total_n)
    return total_abs / total_n   # per-target MAE

mae_ht = cv_mae(pipe_ht, X, Y_ht)  # [MAE_HT_home, MAE_HT_away]
mae_ft = cv_mae(pipe_ft, X, Y_ft)  # [MAE_FT_home, MAE_FT_away]

print(f"HT MAE home/away: {mae_ht[0]:.3f} / {mae_ht[1]:.3f}")
print(f"FT MAE home/away: {mae_ft[0]:.3f} / {mae_ft[1]:.3f}")
# Out:
# [163.23671098 134.27504299]
# 25
# [333.95639021 286.90103644]
# 50
# [463.82674886 470.71627784]
# 75
# [666.6983664  638.84680315]
# 100
# [866.83707924 789.1999884 ]
# 125
# [248.00944444 203.22568585]
# 25
# [517.89800992 368.99565807]
# 50
# [707.67820016 551.39643308]
# 75
# [972.1207601  796.83731999]
# 100
# [1246.90565176  963.03485113]
# 125
# HT MAE home/away: 6.935 / 6.314
# FT MAE home/away: 9.975 / 7.704
